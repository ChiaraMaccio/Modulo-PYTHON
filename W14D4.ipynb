# %% [markdown]
# # W14D4 - ESERCIZIO 2 WEEK 10

# %%
from sqlalchemy import create_engine
import dotenv
import os
import pandas as pd
dotenv.load_dotenv(override=True)
username = os.getenv('username')
password = os.getenv('password')
host = os.getenv('host')
dbname = os.getenv('dbname')

import pandas as pd
dbname = "AdventureWorksDW"
conn_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"
db_engine = create_engine(conn_string)
query = """SELECT *
        FROM dimproduct
        """
df = pd.read_sql(query, db_engine)
df
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                    None                None        Adjustable Race
# 1                    None                None           Bearing Ball
# ...

# %% [markdown]
# ### ESPLORAZIONE DELLA TABELLA
# #### esercizio 1/3

# %%
#Quanti dati ci sono in totale?

df.shape
# Out:
# (606, 36)

# %%
#Quali sono i metadati?

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606 entries, 0 to 605
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             606 non-null    int64
#  1   ProductAlternateKey    606 non-null    object
#  2   ProductSubcategoryKey  397 non-null    float64
#  3   WeightUnitMeasureCode  282 non-null    object
#  4   SizeUnitMeasureCode    253 non-null    object
#  5   EnglishProductName     606 non-null    object
#  6   SpanishProductName     606 non-null    object
#  7   FrenchProductName      606 non-null    object
#  8   StandardCost           397 non-null    float64
#  9   FinishedGoodsFlag      606 non-null    int64
#  10  Color                  606 non-null    object
#  11  SafetyStockLevel       606 non-null    int64
#  12  ReorderPoint           606 non-null    int64
#  13  ListPrice              395 non-null    float64
# ...

# %%
list(df.columns)
# Out:
# ['ProductKey',
#  'ProductAlternateKey',
#  'ProductSubcategoryKey',
#  'WeightUnitMeasureCode',
#  'SizeUnitMeasureCode',
#  'EnglishProductName',
#  'SpanishProductName',
#  'FrenchProductName',
#  'StandardCost',
#  'FinishedGoodsFlag',
#  'Color',
#  'SafetyStockLevel',
#  'ReorderPoint',
#  'ListPrice',
#  'Size',
#  'SizeRange',
#  'Weight',
#  'DaysToManufacture',
#  'ProductLine',
#  'DealerPrice',
#  'Class',
#  'Style',
#  'ModelName',
#  'LargePhoto',
#  'EnglishDescription',
#  'FrenchDescription',
#  'ChineseDescription',
#  'ArabicDescription',
#  'HebrewDescription',
#  'ThaiDescription',
#  'GermanDescription',
#  'JapaneseDescription',
#  'TurkishDescription',
#  'StartDate',
#  'EndDate',
#  'Status']

# %%
df.columns.tolist()
# Out:
# ['ProductKey',
#  'ProductAlternateKey',
#  'ProductSubcategoryKey',
#  'WeightUnitMeasureCode',
#  'SizeUnitMeasureCode',
#  'EnglishProductName',
#  'SpanishProductName',
#  'FrenchProductName',
#  'StandardCost',
#  'FinishedGoodsFlag',
#  'Color',
#  'SafetyStockLevel',
#  'ReorderPoint',
#  'ListPrice',
#  'Size',
#  'SizeRange',
#  'Weight',
#  'DaysToManufacture',
#  'ProductLine',
#  'DealerPrice',
#  'Class',
#  'Style',
#  'ModelName',
#  'LargePhoto',
#  'EnglishDescription',
#  'FrenchDescription',
#  'ChineseDescription',
#  'ArabicDescription',
#  'HebrewDescription',
#  'ThaiDescription',
#  'GermanDescription',
#  'JapaneseDescription',
#  'TurkishDescription',
#  'StartDate',
#  'EndDate',
#  'Status']

# %%
df.dtypes
# Out:
# ProductKey                        int64
# ProductAlternateKey              object
# ProductSubcategoryKey           float64
# WeightUnitMeasureCode            object
# SizeUnitMeasureCode              object
# EnglishProductName               object
# SpanishProductName               object
# FrenchProductName                object
# StandardCost                    float64
# FinishedGoodsFlag                 int64
# Color                            object
# SafetyStockLevel                  int64
# ReorderPoint                      int64
# ListPrice                       float64
# Size                             object
# SizeRange                        object
# Weight                          float64
# DaysToManufacture                 int64
# ProductLine                      object
# DealerPrice                     float64
# Class                            object
# Style                            object
# ModelName                        object
# ...

# %%
df.describe()['StandardCost']
# Out:
# count     397.000000
# mean      436.823073
# min         0.860000
# 25%        37.120000
# 50%       204.630000
# 75%       660.910000
# max      2171.290000
# std       497.343079
# Name: StandardCost, dtype: float64

# %%
#Stampiamo il primo elemento

df.head(1)
# Out:
#    ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0           1             AR-5381                    NaN
#
#   WeightUnitMeasureCode SizeUnitMeasureCode EnglishProductName  \
# 0                  None                None    Adjustable Race
#
#   SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  ...  \
# 0                                                NaN                  0  ...
#
#   ChineseDescription  ArabicDescription  HebrewDescription  ThaiDescription  \
# 0               None               None               None             None
#
#   GermanDescription JapaneseDescription  TurkishDescription  StartDate  \
# 0              None                None                None 2003-07-01
#
#   EndDate   Status
# 0     NaT  Current
#
# [1 rows x 36 columns]

# %%
#Stampiamo l'ultimo elemento

df.tail(1)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode  EnglishProductName  \
# 605                    LB                  CM  Road-750 Black, 52
#
#             SpanishProductName           FrenchProductName  StandardCost  \
# 605  Carretera: 750, negra, 52  Vélo de route 750 noir, 52        343.65
#
#      FinishedGoodsFlag  ...                 ChineseDescription  \
# 605                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
#
#                                      ArabicDescription  \
# 605  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
#
#                                      HebrewDescription  \
# 605  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
#
#                                        ThaiDescription  \
# 605  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
#
#                                      GermanDescription  \
# ...

# %%
#Riusciamo a stampare cinque elementi a caso?

df.sample(5)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 79           80             HU-8998                    NaN
# 12           13             CS-2812                    NaN
# 512         513          FR-M63S-46                   12.0
# 0             1             AR-5381                    NaN
# 305         306          FR-M94B-38                   12.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode  \
# 79                   None                None
# 12                   None                None
# 512                    LB                  CM
# 0                    None                None
# 305                    LB                  CM
#
#                    EnglishProductName SpanishProductName FrenchProductName  \
# 79                             HL Hub
# 12                        Chain Stays
# 512  ML Mountain Frame-W - Silver, 46
# 0                     Adjustable Race
# 305     HL Mountain Frame - Black, 38
#
#      StandardCost  FinishedGoodsFlag  ...  \
# ...

# %%
df.sample(7,random_state =15)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 285         286          FR-R38B-52                   14.0
# 541         542             PD-M282                   13.0
# 398         399             HB-M763                    4.0
# 174         175             PA-823Y                    NaN
# 272         273          FR-R38R-62                   14.0
# 115         116             LJ-9161                    NaN
# 191         192             SA-R522                    NaN
#
#     WeightUnitMeasureCode SizeUnitMeasureCode         EnglishProductName  \
# 285                    LB                  CM  LL Road Frame - Black, 52
# 541                     G                None          LL Mountain Pedal
# 398                  None                None     ML Mountain Handlebars
# 174                  None                None             Paint - Yellow
# 272                    LB                  CM    LL Road Frame - Red, 62
# ...

# %%
df.nunique()
# Out:
# ProductKey               606
# ProductAlternateKey      504
# ProductSubcategoryKey     37
# WeightUnitMeasureCode      2
# SizeUnitMeasureCode        1
# EnglishProductName       504
# SpanishProductName       238
# FrenchProductName        238
# StandardCost             131
# FinishedGoodsFlag          2
# Color                     10
# SafetyStockLevel           6
# ReorderPoint               6
# ListPrice                119
# Size                      18
# SizeRange                 11
# Weight                   127
# DaysToManufacture          4
# ProductLine                4
# DealerPrice              120
# Class                      3
# Style                      3
# ModelName                119
# LargePhoto                42
# EnglishDescription       114
# FrenchDescription        113
# ChineseDescription       113
# ArabicDescription        113
# HebrewDescription        113
# ThaiDescription          113
# GermanDescription        113
# JapaneseDescription      114
# ...

# %%
#verificare che la colonna 'ProductKey' sia la key column dati 
#dato che i valori univoci al suo interno = numero righe totali

che_valori_unici_ho = df['ProductKey'].unique()

# %%
#verificare che la colonna 'ProductKey' sia la key column dati 
#dato che i valori univoci al suo interno = numero righe totali

len(che_valori_unici_ho) == df['ProductKey'].nunique()
# Out:
# True

# %%
df['Weight'].value_counts()
# Out:
# Weight
# 2.30      8
# 2.36      6
# 2.68      6
# 2.84      6
# 2.72      6
#          ..
# 189.00    1
# 149.00    1
# 88.00     1
# 600.00    1
# 20.42     1
# Name: count, Length: 127, dtype: int64

# %%
df['Weight'].value_counts()[2.84]
# Out:
# 6

# %%
#Quali sono i colori disponibili?

df['Color'].value_counts()
# Out:
# Color
# NA              254
# Black           133
# Red              63
# Silver           52
# Yellow           46
# Blue             28
# Multi            18
# Silver/Black      7
# White             4
# Grey              1
# Name: count, dtype: int64

# %%
df['Color'].unique()
# Out:
# array(['NA', 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow',
#        'Grey', 'Silver/Black'], dtype=object)

# %% [markdown]
# ### esercizio 2/3

# %%
#In media quanto pesano i prodotti?

df['Weight'].mean()
# Out:
# 56.1932269503546

# %%
#Quanto pesa il più leggero?

df['Weight'].min()
# Out:
# 2.12

# %%
#Quanto pesa il più pesante?

df['Weight'].max()
# Out:
# 1050.0

# %%
#oppure

df['Weight'].describe()
# Out:
# count     282.000000
# mean       56.193227
# std       158.000652
# min         2.120000
# 25%         2.680000
# 50%        15.420000
# 75%        24.130000
# max      1050.000000
# Name: Weight, dtype: float64

# %%
#Quanti prodotti pesano più di 100 Kg?

print('i pesi superiori a 100 kg sono:')

for peso in df['Weight']:
    if peso > 100:
        print(peso)
# Out:
# i pesi superiori a 100 kg sono:
# 435.0
# 450.0
# 400.0
# 445.0
# 450.0
# 400.0
# 460.0
# 900.0
# 850.0
# 650.0
# 1050.0
# 1000.0
# 890.0
# 215.0
# 317.0
# 218.0
# 215.0
# 185.0
# 189.0
# 168.0
# 149.0
# 317.0
# 600.0
# 635.0
# 575.0
# 223.0
# 168.0
# 170.0

# %%
#oppure
#Quanti prodotti pesano più di 100 Kg?
#creo maschera

valori_magg_100=df['Weight'] >100
valori_magg_100.value_counts()
# Out:
# Weight
# False    578
# True      28
# Name: count, dtype: int64

# %%
#oppure
#Quanti prodotti pesano più di 100 Kg?

quali_piu_100= df.loc[valori_magg_100]
len(quali_piu_100)
# Out:
# 28

# %%
#Quanto costano in media i prodotti (colonna DealerPrice)?

df['DealerPrice'].mean()
# Out:
# 448.5970597468353

# %%
#oppure 

df['DealerPrice'].describe()
# Out:
# count     395.000000
# mean      448.597060
# std       503.225071
# min         1.374000
# 25%        41.994000
# 50%       218.454000
# 75%       722.594900
# max      2146.962000
# Name: DealerPrice, dtype: float64

# %%
#Se prendiamo un quarto di tutti i prodotti, in modo che 
#siano i più costosi,quale sarà il loro range di prezzo?

#utilizzando describe() ho già la divisione in quarti, 
#considero i quarti più alti: da 75% al valore max

#oppure lo estraggo singolarmente
prezzo_desc = df['DealerPrice'].describe()
prezzo_desc['75%']
# Out:
# 722.5949

# %% [markdown]
# #### esercizio 3/3

# %%
colore_indice = df.set_index('Color')
colore_indice.sample()
# Out:
#        ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# Color
# NA            175             PA-823Y                    NaN
#
#       WeightUnitMeasureCode SizeUnitMeasureCode EnglishProductName  \
# Color
# NA                     None                None     Paint - Yellow
#
#       SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  \
# Color
# NA                                                   NaN                  0
#
#        ...  ChineseDescription  ArabicDescription  HebrewDescription  \
# Color  ...
# NA     ...                None               None               None
#
#       ThaiDescription GermanDescription  JapaneseDescription  \
# Color
# NA               None              None                 None
#
#        TurkishDescription  StartDate  EndDate   Status
# Color
# NA                   None 2003-07-01      NaT  Current
#
# [1 rows x 35 columns]

# %%
# Qual è il prezzo medio per i prodotti di colore blu?

prodotti_blu = df['Color'] == 'Blue'
df_blu= df.loc[prodotti_blu]
df_blu
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 219         220           HL-U509-B                   31.0
# 220         221           HL-U509-B                   31.0
# 221         222           HL-U509-B                   31.0
# 470         471           VE-C304-S                   25.0
# 471         472           VE-C304-M                   25.0
# 472         473           VE-C304-L                   25.0
# 496         497          FR-T98U-46                   16.0
# 497         498          FR-T98U-50                   16.0
# 498         499          FR-T98U-54                   16.0
# 499         500          FR-T98U-60                   16.0
# 501         502          FR-T67U-50                   16.0
# 502         503          FR-T67U-54                   16.0
# 503         504          FR-T67U-58                   16.0
# 504         505          FR-T67U-62                   16.0
# 509         510          FR-T67U-44                   16.0
# ...

# %%
# Qual è il prezzo medio per i prodotti di colore blu?

prezzo_medio_blu = df_blu['DealerPrice'].mean()
print('il prezzo medio dei prodotti blu è:', prezzo_medio_blu)
# Out:
# il prezzo medio dei prodotti blu è: 516.0631785714286

# %%
#Qual è il prezzo medio per i prodotti di colore rosso o nero?
#es corretto 

filtro_rosso = df['Color'] == 'Red'
filtro_nero = df['Color'] == 'Black'

filtro_re_black = df[(filtro_rosso) | (filtro_nero)]

prezzo_re_black = filtro_re_black['DealerPrice'].mean()
print('il prezzo medio dei prodotti rossi o neri è:', prezzo_re_black)
# Out:
# il prezzo medio dei prodotti rossi o neri è: 550.2481873684211

# %%
# Qual è il prezzo medio per i prodotti di colore nero?

prezzo_medio_nero = df[df['Color'] == 'Black']['DealerPrice'].mean()

print('il prezzo medio dei prodotti neri è:', prezzo_medio_nero)
# Out:
# il prezzo medio dei prodotti neri è: 474.8236875

# %%
# Qual è il prezzo medio per i prodotti di colore rosso?

prezzo_medio_rosso=df[df['Color'] == 'Red']['DealerPrice'].mean()
print('il prezzo medio dei prodotti rossi è:', prezzo_medio_rosso)
# Out:
# il prezzo medio dei prodotti rossi è: 705.9632838709679

# %%
#Qual è il prezzo massimo per i prodotti di taglia 42 e peso oltre i 10 Kg?
#es corretto

taglia_42 = df['Size'] == '42'
peso_oltre_10= df['Weight'] > 10

df_42_10 =df[taglia_42 & peso_oltre_10]

df_42_10['DealerPrice'].describe()

#potrei usare anche .max()
# Out:
# count      12.000000
# mean     1060.343267
# std       599.030160
# min       323.994000
# 25%       565.620375
# 50%      1125.026450
# 75%      1380.744000
# max      2039.994000
# Name: DealerPrice, dtype: float64

# %%
df_42_10['DealerPrice'].max()
# Out:
# 2039.994

# %%
#Qual è il nome inglese e il costo di produzione (StandardCost) di tutti 
# i prodotti di taglia 42, peso oltre i 10 Kg e colore argento?

taglia_42 = df['Size'] == '42'
peso_oltre_10= df['Weight'] > 10
colore_argento= df['Color'] == 'Silver'

condizioni = df[(taglia_42) & (peso_oltre_10) & (colore_argento)]
risultato = condizioni[['EnglishProductName', 'StandardCost']]
print('Il prezzo dei prodotti argento di taglia 42 che pesano più di 10 kg è:',risultato)
# Out:
# Il prezzo dei prodotti argento di taglia 42 che pesano più di 10 kg è:             EnglishProductName  StandardCost
# 344    Mountain-100 Silver, 42       1912.15
# 353    Mountain-200 Silver, 42       1117.86
# 354    Mountain-200 Silver, 42       1265.62
# 588  Mountain-400-W Silver, 42        419.78
# 591    Mountain-500 Silver, 42        308.22

# %%
#oppure, es corretto

taglia_42 = df['Size'] == '42'
peso_oltre_10= df['Weight'] > 10
colore_argento= df['Color'] == 'Silver'

argento_42_10 = df.loc[taglia_42&peso_oltre_10&colore_argento]

argento_42_10[['EnglishProductName', 'StandardCost']]
# Out:
#             EnglishProductName  StandardCost
# 344    Mountain-100 Silver, 42       1912.15
# 353    Mountain-200 Silver, 42       1117.86
# 354    Mountain-200 Silver, 42       1265.62
# 588  Mountain-400-W Silver, 42        419.78
# 591    Mountain-500 Silver, 42        308.22

# %%
# Esaminiamo la differenza tra lo StandardCost e il DealerPrice degli 
# ultimi 20 elementi del dataset: c'è un pattern? 
# C'è qualche elemento che non lo segue?

differenza_prezzi = df.tail(20)[['DealerPrice', 'StandardCost']]
differenza_prezzi

#dealer price sempre più alto tranne gli ultimi 3
# Out:
#      DealerPrice  StandardCost
# 586      461.694        419.78
# 587      461.694        419.78
# 588      461.694        419.78
# 589      461.694        419.78
# 590      338.994        308.22
# 591      338.994        308.22
# 592      338.994        308.22
# 593      338.994        308.22
# 594      338.994        308.22
# 595      323.994        294.58
# 596      323.994        294.58
# 597      323.994        294.58
# 598      323.994        294.58
# 599      323.994        294.58
# 600       32.394         23.97
# 601       60.744         44.95
# 602       72.894         53.94
# 603      323.994        343.65
# 604      323.994        343.65
# 605      323.994        343.65

# %% [markdown]
# ### analisi utile per vedere se ci sono anomalie e andare ad analizzarle
# #### es qua ultimi 3 prodotti vanno contro tendenza, andare ad analizzare
# #### - che prodotti sono
# #### - se accade altre volte
# #### - quante volte accade

# %%
differenza_prezzi = df.tail(20)[['DealerPrice', 'StandardCost']].plot()

# %% [markdown]
# # IMPORTARE CSV AMAZON

# %%
percorso_file = r"C:\Users\Chiara\OneDrive\Desktop\EPICODE\MODULO IV - Phyton\Week 10\Esercizi 10\Materiali W14D4\beginner_datasets\amazon.csv"
df_amz = pd.read_csv(percorso_file)

df_amz
# Out:
#                                               reviewText  Positive
# 0      This is a one of the best apps acording to a b...         1
# 1      This is a pretty good version of the game for ...         1
# 2      this is a really cool game. there are a bunch ...         1
# 3      This is a silly game and can be frustrating, b...         1
# 4      This is a terrific game on any pad. Hrs of fun...         1
# ...                                                  ...       ...
# 19995  this app is fricken stupid.it froze on the kin...         0
# 19996  Please add me!!!!! I need neighbors! Ginger101...         1
# 19997  love it!  this game. is awesome. wish it had m...         1
# 19998  I love love love this app on my side of fashio...         1
# 19999  This game is a rip off. Here is a list of thin...         0
#
# [20000 rows x 2 columns]

# %%
# Valutiamo la dimensione del dataset

df_amz.shape
# Out:
# (20000, 2)

# %%
df_amz.sample(10)

# %%
#Osserviamo quali sono i nomi di colonna

list(df_amz.columns)
# Out:
# ['reviewText', 'Positive']

# %%
df_amz.describe()
# Out:
#            Positive
# count  20000.000000
# mean       0.761650
# std        0.426085
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
df_amz.nunique()
# Out:
# reviewText    20000
# Positive          2
# dtype: int64

# %%
lista_valori_unici=df_amz['reviewText'].unique()
len(lista_valori_unici)== df_amz['reviewText'].nunique()
# Out:
# True

# %%
#Il dataset è bilanciato, ovvero, il numero di recensioni positive è uguale 
#a quello delle negative, oppure no?
# 0 --> false 
# 1 --> true


rece_positive = df_amz[df_amz['Positive'] == 1]
rece_negative = df_amz[df_amz['Positive'] == 0]
len(rece_positive)==len(rece_negative)
# Out:
# False

# %%
#oppure
#es corretto

df_amz.Positive.value_counts()
# Out:
# Positive
# 1    15233
# 0     4767
# Name: count, dtype: int64

# %% [markdown]
# ## IMPORTARE DATASET DIABETES.CSV

# %%
percorso_file=r"C:\Users\Chiara\OneDrive\Desktop\EPICODE\MODULO IV - Phyton\Week 10\Esercizi 10\Materiali W14D4\beginner_datasets\diabetes.csv"

df_dt= pd.read_csv(percorso_file)

df_dt
# Out:
#      Number of times pregnant  \
# 0                           6
# 1                           1
# 2                           8
# 3                           1
# 4                           0
# ..                        ...
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 1                                                   85
# 2                                                  183
# 3                                                   89
# 4                                                  137
# ..                                                 ...
# 763                                                101
# 764                                                122
# 765                                                121
# ...

# %%
#Osserviamone le dimensioni 

df_dt.shape
# Out:
# (768, 9)

# %%
# un'anteprima di cinque righe
df_dt.head(5)
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
df_dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Number of times pregnant                                                  768 non-null    int64
#  1   Plasma glucose concentration a 2 hours in an oral glucose tolerance test  768 non-null    int64
#  2   Diastolic blood pressure (mm Hg)                                          768 non-null    int64
#  3   Triceps skin fold thickness (mm)                                          768 non-null    int64
#  4   2-Hour serum insulin (mu U/ml)                                            768 non-null    int64
#  5   Body mass index (weight in kg/(height in m)^2)                            768 non-null    float64
# ...

# %%
list(df_dt.columns)
# Out:
# ['Number of times pregnant',
#  'Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
#  'Diastolic blood pressure (mm Hg)',
#  'Triceps skin fold thickness (mm)',
#  '2-Hour serum insulin (mu U/ml)',
#  'Body mass index (weight in kg/(height in m)^2)',
#  'Diabetes pedigree function',
#  'Age (years)',
#  'Class variable']

# %%
#Stampiamo dei descrittori statistici del dataset

df_dt.describe()
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# ...

# %%
#Selezioniamo i dati relativi a diverse fasce di età: 
#<20, 20-30, 30-40, 40-50, >50;

under_20 =df_dt.loc[df_dt['Age (years)']< 20]
quanti_under_20 = len(under_20)

# %%
fascia20_30= df_dt.loc[(df_dt['Age (years)'] >= 20) & (df_dt['Age (years)'] <30)]
quanti_20_30= len(fascia20_30)

# %%
fascia30_40= df_dt.loc[(df_dt['Age (years)']>=30) & (df_dt['Age (years)'] <40)]
quanti_30_40= len(fascia30_40)

# %%
fascia40_50= df_dt.loc[(df_dt['Age (years)'] >= 40)&(df_dt['Age (years)'] < 50)]
quanti_40_50= len(fascia40_50)

# %%
over_50= df_dt.loc[df_dt['Age (years)'] >= 50]
quanti_over_50= len(over_50)

# %%
#test per vedere di non avere dati ripetuti o mancanti

quanti_over_50 + quanti_40_50 + quanti_30_40 + quanti_20_30 + quanti_under_20
# Out:
# 768

# %%
#oppure
#correzione es
under_20 = df_dt['Age (years)']< 20
fascia20_30= (20 <= df_dt['Age (years)']) & (df_dt['Age (years)']  <30)
fascia30_40= (30 <= df_dt['Age (years)']) & (df_dt['Age (years)']  <40)
fascia40_50= (40 <= df_dt['Age (years)']) & (df_dt['Age (years)']  <50)
over_50= df_dt['Age (years)'] >= 50

df_dt.loc[fascia30_40]
# Out:
#      Number of times pregnant  \
# 1                           1
# 2                           8
# 4                           0
# 5                           5
# 10                          4
# ..                        ...
# 748                         3
# 755                         1
# 756                         7
# 762                         9
# 765                         5
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 1                                                   85
# 2                                                  183
# 4                                                  137
# 5                                                  116
# 10                                                 110
# ..                                                 ...
# 748                                                187
# 755                                                128
# 756                                                137
# ...

# %%
# Qual è la media della pressione sanguigna diastolica per le diverse fasce di età?

# %%
ps_under_20 = df_dt.loc [under_20,'Diastolic blood pressure (mm Hg)'].mean()
ps_under_20
# Out:
# nan

# %%
ps_20_30= df_dt.loc[fascia20_30, 'Diastolic blood pressure (mm Hg)'].mean()
ps_20_30
# Out:
# 65.34848484848484

# %%
ps_30_40=df_dt.loc[fascia30_40,'Diastolic blood pressure (mm Hg)'].mean()
ps_30_40
# Out:
# 69.66666666666667

# %%
ps_40_50= df_dt.loc[fascia40_50, 'Diastolic blood pressure (mm Hg)'].mean()
ps_40_50
# Out:
# 73.94067796610169

# %%
ps_over_50= df_dt.loc[over_50, 'Diastolic blood pressure (mm Hg)'].mean()
ps_over_50
# Out:
# 78.37078651685393

# %%
#oppure
#correzione es
#automatizziamo l'operazione creando dizionario e ciclo for

filtri= {'meno_20' : under_20, 
'20-30' : fascia20_30,
'30-40' : fascia30_40,
'40-50': fascia40_50,
'piu_50': over_50}

for nome_filtro in filtri:
    print(nome_filtro, end=':')
    filtro= filtri[nome_filtro]
    media= df_dt.loc[filtro, 'Diastolic blood pressure (mm Hg)'].mean()
    print(media)
# Out:
# meno_20:nan
# 20-30:65.34848484848484
# 30-40:69.66666666666667
# 40-50:73.94067796610169
# piu_50:78.37078651685393

# %%
# Calcola la media della pressione sanguigna diastolica per ogni singola età
media_ps_per_eta = df_dt.groupby('Age (years)')['Diastolic blood pressure (mm Hg)'].mean()
media_ps_per_eta
# Out:
# Age (years)
# 21    65.936508
# 22    63.722222
# 23    64.315789
# 24    64.956522
# 25    59.666667
# 26    64.181818
# 27    73.500000
# 28    68.314286
# 29    68.241379
# 30    64.857143
# 31    64.375000
# 32    70.062500
# 33    65.647059
# 34    74.000000
# 35    75.600000
# 36    69.125000
# 37    75.947368
# 38    71.125000
# 39    72.666667
# 40    69.230769
# 41    67.590909
# 42    73.388889
# 43    78.461538
# 44    61.750000
# 45    83.066667
# 46    76.000000
# 47    78.333333
# 48    78.400000
# 49    81.400000
# 50    78.250000
# 51    84.500000
# 52    81.500000
# 53    79.000000
# 54    89.333333
# 55    70.250000
# 56    76.333333
# 57    76.800000
# 58    78.285714
# 59    74.000000
# 60    80.000000
# 61    76.000000
# 62    71.500000
# 63    78.000000
# 64    78.000000
# 65    78.666667
# 66    86.000000
# 67    72.666667
# 68    82.000000
# 69    81.000000
# 70    82.000000
# 72     0.000000
# 81    74.000000
# ...

# %%
#se volessi selezionare solo determinati range di età

media_ps_per_eta.loc[29:37]
# Out:
# Age (years)
# 29    68.241379
# 30    64.857143
# 31    64.375000
# 32    70.062500
# 33    65.647059
# 34    74.000000
# 35    75.600000
# 36    69.125000
# 37    75.947368
# Name: Diastolic blood pressure (mm Hg), dtype: float64

# %% [markdown]
# ### IMPORTARE DATASET INSURANCE.CSV

# %%
percorso_file=r"C:\Users\Chiara\OneDrive\Desktop\EPICODE\MODULO IV - Phyton\Week 10\Esercizi 10\Materiali W14D4\beginner_datasets\insurance.csv"
df_in=pd.read_csv(percorso_file)
df_in
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#Visualizziamone le dimensioni, un'anteprima, e osserviamo i nomi di colonna;

df_in.shape
# Out:
# (1338, 7)

# %%
#un'anteprima

df_in.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# osserviamo i nomi di colonna

list(df_in.columns)
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']

# %%
df_in['charges'].mean()
# Out:
# 13270.422265141257

# %%
raggruppamento_regioni= df_in.groupby('region')['region'].value_counts()

raggruppamento_regioni
# Out:
# region
# northeast    324
# northwest    325
# southeast    364
# southwest    325
# Name: count, dtype: int64

# %%
#Quali sono le medie di charges rispetto a region? 
#Ci sono differenze significative?

media_regioni= df_in.groupby('region')['charges'].mean()

media_regioni
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %%
# rispetto a smoker

media_smokers = df_in.groupby('smoker')['charges'].mean()
media_smokers
# Out:
# smoker
# no      8434.268298
# yes    32050.231832
# Name: charges, dtype: float64

# %%
#rispetto a sex

media_sex = df_in.groupby('sex')['charges'].mean()
media_sex
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %%
#Quali sono i descrittori statistici di bmi?

df_in.bmi.describe()
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %%
# Quali sono minimo, media e massimo di charges 
#rispetto ai diversi quartili dei valori di bmi?

df_in.charges.describe()
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %% [markdown]
# ### IMPORTARE DATASET POKEMON.CSV

# %%
file= r"C:\Users\Chiara\OneDrive\Desktop\EPICODE\MODULO IV - Phyton\Week 10\Esercizi 10\Materiali W14D4\beginner_datasets\pokemon.csv"

poke = pd.read_csv(file)

poke
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
#verifichiamo la dimensione

poke.shape

# %%
poke.info()

# %%
#verifichiamo un'anteprima

poke.head(5)

# %%
#verifichiamo nomi colonne

list(poke.columns)

# %%
# È verosimile che la prima colonna dovrebbe essere un indice?

poke.nunique()

# %%
poke['#'].tail(10)

# %%
poke = poke.set_index('#')
poke

# %%
#Quali sono i Pokémon leggendari?

pokemon_legendary = poke[poke['Legendary'] == True]

pokemon_legendary

# %%
#E quali sono i leggendari di tipo 1 Grass?

legend_grass= poke[(poke['Legendary'] == True) & (poke['Type 1'] == 'Grass')]

legend_grass

# %%
#E leggendari di tipo 1 Ice o Fire?

leg_ice_fire = poke[(poke['Legendary'] == True) & ((poke['Type 1'] == 'Ice')|(poke['Type 1'] == 'Fire'))]

leg_ice_fire

# %%
#Ordiniamo il dataset per la colonna Name

ordinare_name = poke.sort_values(by='Name')

ordinare_name

# %%
#Trasformiamo Name nell'indice

name_index = poke.set_index('Name')

name_index

# %%
#Quali sono i Pokémon della prima generazione con attacco > 50 e HP < 60?

prima_gen = poke[(poke[ 'Generation'] == 1) & (poke['Attack'] > 50) & (poke['HP']<60)]

prima_gen
